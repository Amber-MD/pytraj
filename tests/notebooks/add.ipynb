# %%
import pytraj as pt

traj = pt.load('../data/polyAT.pdb')
traj.translate('x 20')
view = traj.view()
view

# %%
view.add('../data/1L2Y.pdb')

# %%
view.component_1.clear_representations()
view.component_1.add_tube()

# %%
view.orientation = [[2.405843167696504, -29.40068079644591, -41.26384674643627],
 [0.05841986906605263, 0.8146345881230026, -0.5770247886633243],
 [-10.027213096618652, -0.6201138496398926, -13.090391874313354],
 [0, 0, 0]]

# %%
view.render_image()

# %%
view._display_image()
