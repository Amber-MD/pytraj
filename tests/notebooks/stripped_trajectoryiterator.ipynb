# %%
import pytraj as pt

traj = pt.datafiles.load_tz2_ortho()

t2 = pt.replicate_cell(traj, direction='all')

traj2 = traj.autoimage().superpose('@CA').strip(":WAT")

view = traj2.view()
view

# %%
view.clear()
view.add_licorice()
view.render_image()

# %%
view._display_image()
