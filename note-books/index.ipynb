# %% [markdown]
# [FAQ](FAQ.ipynb)
#
# # Overview
# [quick_overview](pytraj_overview_shorter.ipynb)
#
# [longer_overview](pytraj_overview.ipynb)
#
# [install_test](install_test.ipynb)
#
# [Topology](Topology.ipynb)
#
#
# [Trajectory](Trajectory.ipynb)
#
# [atom_mask_selection](atom_mask_selection.ipynb)
#
# [fancy_indexing](fancy_indexing.ipynb)
#
# [slicing_Trajectory](slicing_Trajectory.ipynb)
#
#
# # I/O
# [saving_data_or_traj](saving_data_or_traj.ipynb)
#
# [load_remd_traj](load_remd_traj.ipynb)
#
# [load_pdb_from_rcsb](load_pdb_from_rcsb.ipynb)
#
# [iterload](iterload.ipynb)
#
# [load_a_list_of_files](load_a_list_of_files.ipynb)
#
# [load_cpptraj_file_for_laziness](load_cpptraj_file_for_laziness.ipynb)
#
#
# # Data Analysis
#
# [hbond_0](hbond_0.ipynb)
#
# [analysis_rms2d](analysis_rms2d.ipynb)
#
# [dataset](dataset.ipynb)
#
# [dssp](dssp_tutorial.ipynb)
#
# [multidihedral_analysis](multidihedral_analysis.ipynb)
#
# [clustering](clustering.ipynb)
#
# [animation_0](animation_0.ipynb)
#
# [extract_temperature_traj_remd](extract_temperature_traj_remd.ipynb)
#
#
# # Interface
# [numpy_interface](numpy_interface.ipynb)
#
# [interface_with_other_packages](interface_with_other_packages.ipynb)
#
# [calc_energies_pysander](calc_energies_pysander.ipynb)
#
#
# # Parallel
# [parallel_ipython](parallel_ipython.ipynb)
#
# [parallel/rmsd_mpi](parallel/rmsd_mpi.ipynb)
#
# [parallel/mpi_calc_molsurf](parallel/mpi_calc_molsurf.ipynb)
#
# # Speed Test and Performance
#
# [memory_comparison](memory_comparison.ipynb)
#
# [performance_tips](performance_tips.ipynb)
#
# [speed_test_2_trajs](speed_test_2_trajs.ipynb)
#
# [speed_test](speed_test.ipynb)
#
# [dev/speed_test_distance](dev/speed_test_distance.ipynb)
#
#
# # Misc
# [pytraj_plot](pytraj_plot.ipynb)
#
# [animation_0](animation_0.ipynb)
