# %% [markdown]
# <span style="color:blue; font-family:Georgia; font-size:3em;"> **Calculate pairwise RMSD for trajectory and plot** </span>

# %%
import pytraj as pt
from pytraj.plot import plot_matrix

# %%
traj = pt.iterload("../tests/data/md1_prod.Tc5b.x", "../tests/data/Tc5b.top")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-bda79e60ed5d> in <module>()
# ----> 1 traj = pt.iterload("../tests/data/md1_prod.Tc5b.x", "../tests/data/Tc5b.top")
#
# /home/haichit/anaconda3/lib/python3.4/site-packages/pytraj/io.py in iterload(*args, **kwd)
#     118         raise ValueError(
#     119             "do not support indices for TrajectoryIterator loading")
# --> 120     return load_traj(*args, **kwd)
#     121
#     122
#
# /home/haichit/anaconda3/lib/python3.4/site-packages/pytraj/io.py in load_traj(filename, top, frame_indices, *args, **kwd)
#     181         ts.load(filename, frame_slice=kwd['frame_slice'])
#     182     else:
# --> 183         ts.load(filename)
#     184
#     185     if frame_indices is not None:
#
# /home/haichit/anaconda3/lib/python3.4/site-packages/pytraj/TrajectoryIterator.py in load(self, filename, top, frame_slice)
#     149             if not flist:
#     150                 raise ValueError(
# --> 151                     "must provie a filename or list of filenames or file pattern")
#     152             self.load(flist, top=top, frame_slice=frame_slice)
#     153         else:
#
# ValueError: must provie a filename or list of filenames or file pattern

# %%
mat = pt.pairwise_rmsd(traj, '@CA')
mat
# Out:
# array([[ 0.        ,  0.26412389,  0.3859688 , ...,  0.44428977,
#          0.43628621,  0.44746086],
#        [ 0.26412389,  0.        ,  0.35633412, ...,  0.33826348,
#          0.38432416,  0.40827355],
#        [ 0.3859688 ,  0.35633412,  0.        , ...,  0.38589451,
#          0.48392785,  0.49391907],
#        ...,
#        [ 0.44428977,  0.33826348,  0.38589451, ...,  0.        ,
#          0.25413078,  0.3940194 ],
#        [ 0.43628621,  0.38432416,  0.48392785, ...,  0.25413078,
#          0.        ,  0.32795388],
#        [ 0.44746086,  0.40827355,  0.49391907, ...,  0.3940194 ,
#          0.32795388,  0.        ]], dtype=float32)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' 
import matplotlib
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

fig, asp, axi, = plot_matrix(mat)
fig.colorbar(axi, ax=asp)
